# %%
# %matplotlib inline

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import psycopg2
#import textatistic
import seaborn as sbn
from altair import Chart, X, Y, Color, Scale
import altair as alt
from vega_datasets import data
import requests
from bs4 import BeautifulSoup
matplotlib.style.use('ggplot')
# for plotly py.offline.init_notebook_mode()

# %%
wd = pd.read_csv('protecting_minority_investors.csv')

# %%
wd.head()
# Out:
#               location  protecting_minority_investors_rank  \
# 0          Afghanistan                               140.0
# 1              Albania                               111.0
# 2              Algeria                               179.0
# 3               Angola                               147.0
# 4  Antigua and Barbuda                                79.0
#
#    protecting_minority_investors_score  \
# 0                                 36.0
# 1                                 46.0
# 2                                 20.0
# 3                                 32.0
# 4                                 58.0
#
#    strength_of_minority_investor_protection_index_(0-50)  \
# 0                                                 18
# 1                                                 23
# 2                                                 10
# 3                                                 16
# 4                                                 29
#
#    extent_of_disclosure_index_(0-10)  \
# 0                                  8
# 1                                  9
# 2                                  4
# 3                                  4
# 4                                  4
#
#    extent_of_director_liability_index_(0-10)  \
# 0                                          1
# 1                                          7
# 2                                          1
# 3                                          6
# 4                                          8
#
#    ease_of_shareholder_suits_index_(0-10)  \
# 0                                       9
# 1                                       7
# 2                                       5
# 3                                       6
# 4                                       8
#
#    extent_of_shareholder_rights_index_(0-6)  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         3
#
#    extent_of_ownership_and_control_index_(0-7)  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            4
#
#    extent_of_corporate_transparency_index_(0-7)  starting_a_business_score
# 0                                             0                       92.0
# 1                                             0                       91.8
# 2                                             0                       78.0
# 3                                             0                       79.4
# 4                                             2                       82.6

# %%
wd.describe()
# Out:
#        protecting_minority_investors_rank  \
# count                          190.000000
# mean                            92.973684
# std                             55.125968
# min                              1.000000
# 25%                             45.000000
# 50%                             88.000000
# 75%                            142.250000
# max                            190.000000
#
#        protecting_minority_investors_score  \
# count                           191.000000
# mean                             51.568586
# std                              20.099831
# min                               0.000000
# 25%                              34.000000
# 50%                              56.000000
# 75%                              68.000000
# max                              92.000000
#
#        strength_of_minority_investor_protection_index_(0-50)  \
# count                                         191.000000
# mean                                           25.785340
# std                                            10.050975
# min                                             0.000000
# 25%                                            17.000000
# 50%                                            28.000000
# 75%                                            34.000000
# max                                            46.000000
#
#        extent_of_disclosure_index_(0-10)  \
# count                         191.000000
# mean                            5.827225
# std                             2.562173
# min                             0.000000
# 25%                             4.000000
# 50%                             6.000000
# 75%                             8.000000
# max                            10.000000
#
#        extent_of_director_liability_index_(0-10)  \
# count                                 191.000000
# mean                                    4.732984
# std                                     2.664960
# min                                     0.000000
# 25%                                     2.000000
# 50%                                     5.000000
# 75%                                     7.000000
# max                                    10.000000
#
#        ease_of_shareholder_suits_index_(0-10)  \
# count                              191.000000
# mean                                 6.345550
# std                                  1.907318
# min                                  0.000000
# 25%                                  5.000000
# 50%                                  6.000000
# 75%                                  8.000000
# max                                 10.000000
#
#        extent_of_shareholder_rights_index_(0-6)  \
# count                                191.000000
# mean                                   2.947644
# std                                    2.233096
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    4.000000
# 75%                                    5.000000
# max                                    6.000000
#
#        extent_of_ownership_and_control_index_(0-7)  \
# count                                   191.000000
# mean                                      2.821990
# std                                       2.406075
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       3.000000
# 75%                                       5.000000
# max                                       7.000000
#
#        extent_of_corporate_transparency_index_(0-7)  starting_a_business_score
# count                                    191.000000                 191.000000
# mean                                       3.104712                  84.366492
# std                                        2.593419                  11.250751
# min                                        0.000000                  25.000000
# 25%                                        0.000000                  80.000000
# 50%                                        3.000000                  87.000000
# 75%                                        6.000000                  92.250000
# max                                        7.000000                 100.000000

# %%
c = Chart(wd) # make a chart
m = c.mark_bar() # set the mark -- returns a new Chart
e = m.encode(X('protecting_minority_investors_rank',bin=True),y='count()') # set the encoding
e.display()
# Out:
# alt.Chart(...)

# %%
Chart(wd).mark_bar().encode(x=X('protecting_minority_investors_score', bin=True), y='count()')
# Out:
# alt.Chart(...)

# %%
Chart(wd).mark_point().encode(x='protecting_minority_investors_score', y='starting_a_business_score', tooltip='location')
# Out:
# alt.Chart(...)

# %%
(wd.protecting_minority_investors_score < 50).head(20)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16     True
# 17     True
# 18     True
# 19     True
# Name: protecting_minority_investors_score, dtype: bool

# %%
wd[wd.protecting_minority_investors_score < 20]
# Out:
#                   location  protecting_minority_investors_rank  \
# 52                 Eritrea                               185.0
# 55                Ethiopia                               189.0
# 70                   Haiti                               183.0
# 97                   Libya                               183.0
# 111  Micronesia, Fed. Sts.                               185.0
# 129                  Palau                               188.0
# 154                Somalia                               190.0
# 156            South Sudan                               185.0
#
#      protecting_minority_investors_score  \
# 52                                  16.0
# 55                                  10.0
# 70                                  18.0
# 97                                  18.0
# 111                                 16.0
# 129                                 14.0
# 154                                  0.0
# 156                                 16.0
#
#      strength_of_minority_investor_protection_index_(0-50)  \
# 52                                                   8
# 55                                                   5
# 70                                                   9
# 97                                                   9
# 111                                                  8
# 129                                                  7
# 154                                                  0
# 156                                                  8
#
#      extent_of_disclosure_index_(0-10)  \
# 52                                   3
# 55                                   3
# 70                                   2
# 97                                   4
# 111                                  0
# 129                                  0
# 154                                  0
# 156                                  2
#
#      extent_of_director_liability_index_(0-10)  \
# 52                                           0
# 55                                           0
# 70                                           3
# 97                                           1
# 111                                          0
# 129                                          0
# 154                                          0
# 156                                          1
#
#      ease_of_shareholder_suits_index_(0-10)  \
# 52                                        5
# 55                                        2
# 70                                        4
# 97                                        4
# 111                                       8
# 129                                       7
# 154                                       0
# 156                                       5
#
#      extent_of_shareholder_rights_index_(0-6)  \
# 52                                          0
# 55                                          0
# 70                                          0
# 97                                          0
# 111                                         0
# 129                                         0
# 154                                         0
# 156                                         0
#
#      extent_of_ownership_and_control_index_(0-7)  \
# 52                                             0
# 55                                             0
# 70                                             0
# 97                                             0
# 111                                            0
# 129                                            0
# 154                                            0
# 156                                            0
#
#      extent_of_corporate_transparency_index_(0-7)  starting_a_business_score
# 52                                              0                       52.9
# 55                                              0                       71.7
# 70                                              0                       36.4
# 97                                              0                       73.1
# 111                                             0                       69.6
# 129                                             0                       82.1
# 154                                             0                       46.0
# 156                                             0                       71.0

# %%
Chart(wd[wd.protecting_minority_investors_score < 50]).mark_point().encode(
    x='protecting_minority_investors_score', y='starting_a_business_score', tooltip='location').interactive()
# Out:
# alt.Chart(...)

# %%
wd[(wd.protecting_minority_investors_score < 50) & (wd.starting_a_business_score < 70)]
# Out:
#                      location  protecting_minority_investors_rank  \
# 19                    Bolivia                               136.0
# 28                   Cambodia                               128.0
# 31   Central African Republic                               162.0
# 32                       Chad                               170.0
# 38                Congo, Rep.                               162.0
# 48                    Ecuador                               114.0
# 51          Equatorial Guinea                               162.0
# 52                    Eritrea                               185.0
# 70                      Haiti                               183.0
# 77         Iran, Islamic Rep.                               128.0
# 92                    Lao PDR                               179.0
# 111     Micronesia, Fed. Sts.                               185.0
# 116                Mozambique                               147.0
# 154                   Somalia                               190.0
# 163                  Suriname                               157.0
# 185             Venezuela, RB                               170.0
#
#      protecting_minority_investors_score  \
# 19                                  38.0
# 28                                  40.0
# 31                                  26.0
# 32                                  24.0
# 38                                  26.0
# 48                                  44.0
# 51                                  26.0
# 52                                  16.0
# 70                                  18.0
# 77                                  40.0
# 92                                  20.0
# 111                                 16.0
# 116                                 32.0
# 154                                  0.0
# 163                                 28.0
# 185                                 24.0
#
#      strength_of_minority_investor_protection_index_(0-50)  \
# 19                                                  19
# 28                                                  20
# 31                                                  13
# 32                                                  12
# 38                                                  13
# 48                                                  22
# 51                                                  13
# 52                                                   8
# 70                                                   9
# 77                                                  20
# 92                                                  10
# 111                                                  8
# 116                                                 16
# 154                                                  0
# 163                                                 14
# 185                                                 12
#
#      extent_of_disclosure_index_(0-10)  \
# 19                                   1
# 28                                   6
# 31                                   7
# 32                                   7
# 38                                   7
# 48                                   2
# 51                                   7
# 52                                   3
# 70                                   2
# 77                                   7
# 92                                   6
# 111                                  0
# 116                                  5
# 154                                  0
# 163                                  1
# 185                                  3
#
#      extent_of_director_liability_index_(0-10)  \
# 19                                           5
# 28                                          10
# 31                                           1
# 32                                           1
# 38                                           1
# 48                                           5
# 51                                           1
# 52                                           0
# 70                                           3
# 77                                           4
# 92                                           1
# 111                                          0
# 116                                          4
# 154                                          0
# 163                                          0
# 185                                          2
#
#      ease_of_shareholder_suits_index_(0-10)  \
# 19                                        6
# 28                                        4
# 31                                        5
# 32                                        4
# 38                                        5
# 48                                        6
# 51                                        5
# 52                                        5
# 70                                        4
# 77                                        1
# 92                                        3
# 111                                       8
# 116                                       7
# 154                                       0
# 163                                       6
# 185                                       3
#
#      extent_of_shareholder_rights_index_(0-6)  \
# 19                                          4
# 28                                          0
# 31                                          0
# 32                                          0
# 38                                          0
# 48                                          5
# 51                                          0
# 52                                          0
# 70                                          0
# 77                                          3
# 92                                          0
# 111                                         0
# 116                                         0
# 154                                         0
# 163                                         4
# 185                                         1
#
#      extent_of_ownership_and_control_index_(0-7)  \
# 19                                             1
# 28                                             0
# 31                                             0
# 32                                             0
# 38                                             0
# 48                                             3
# 51                                             0
# 52                                             0
# 70                                             0
# 77                                             3
# 92                                             0
# 111                                            0
# 116                                            0
# 154                                            0
# 163                                            2
# 185                                            2
#
#      extent_of_corporate_transparency_index_(0-7)  starting_a_business_score
# 19                                              2                       69.4
# 28                                              0                       52.4
# 31                                              0                       63.2
# 32                                              0                       52.5
# 38                                              0                       65.8
# 48                                              1                       69.1
# 51                                              0                       61.0
# 52                                              0                       52.9
# 70                                              0                       36.4
# 77                                              2                       67.8
# 92                                              0                       62.7
# 111                                             0                       69.6
# 116                                             0                       69.3
# 154                                             0                       46.0
# 163                                             1                       61.6
# 185                                             1                       25.0

# %%
Chart(wd[(wd.protecting_minority_investors_score < 50) & (wd.starting_a_business_score < 70)]).mark_point().encode(
       x='protecting_minority_investors_score', y='starting_a_business_score', tooltip='location').interactive()
# Out:
# alt.Chart(...)

# %%
wd[wd.location == 'Malta ']
# Out:
# Empty DataFrame
# Columns: [location, protecting_minority_investors_rank, protecting_minority_investors_score, strength_of_minority_investor_protection_index_(0-50), extent_of_disclosure_index_(0-10), extent_of_director_liability_index_(0-10), ease_of_shareholder_suits_index_(0-10), extent_of_shareholder_rights_index_(0-6), extent_of_ownership_and_control_index_(0-7), extent_of_corporate_transparency_index_(0-7), starting_a_business_score]
# Index: []
